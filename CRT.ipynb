# %% [markdown]
# <a href="https://colab.research.google.com/github/sirishan506-source/google-collab/blob/main/CRT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Swaping given two values without using third variable and using bitwise operator

# %%
a=2
b=4
print("original values")
print("a=",a)
print("b=",b)
a=a^b
b=a^b
a=a^b
print("after swaping")
print("a=",a)
print("b=",b)
# Out:
# original values
# a= 2
# b= 4
# after swaping
# a= 4
# b= 2

# %% [markdown]
# swaping in single line statement

# %%
a=2
b=4
print("original values")
print("a=",a)
print("b=",b)
a,b=b,a
print("after swaping")
print("a=",a)
print("b=",b)
# Out:
# original values
# a= 2
# b= 4
# after swaping
# a= 4
# b= 2

# %% [markdown]
# Even or odd using ternary operator

# %%
n=int(input("enter a number:"))
result = "even" if n%2==0 else "odd"
print("given number is:",result)
# Out:
# enter a number:4
# given number is: even

# %% [markdown]
# even or odd using bitwise operator

# %%
n= int(input("enter a number:"))
result= "even" if n&2==0 else "odd"
print("given number is:",result)
# Out:
# enter a number:3
# given number is: odd

# %% [markdown]
# Area of circle , triangle , rectangle and square

# %%
r=float(input("enter radius of circle:"))
a=3.14*r*r
print("area of circle:",a)
b=float(input("enter base of triangle:"))
h=float(input("enter height of triangle:"))
a=0.5*b*h
print("area of triangle:",a)
l=float(input("enter length of rectangle:"))
w=float(input("enter width of rectangle:"))
a=l*w
print("area of rectangle:",a)
s=float(input("enter side of square:"))
a=s*s
print("Area of square:",a)
# Out:
# enter radius of circle:2.5
# area of circle: 19.625
# enter base of triangle:2
# enter height of triangle:4
# area of triangle: 4.0
# enter length of rectangle:5
# enter width of rectangle:2
# area of rectangle: 10.0
# enter side of square:2
# Area of square: 4.0

# %% [markdown]
# perimeter of circle , triangle , rectangle and square

# %%
r=float(input("enter radius of circle:"))
p=2*3.14*r
print("perimeter of circle:",p)
a=float(input("enter 1st side of triangle:"))
b=float(input("enter 2nd side of triangle:"))
c=float(input("enter 3rd side of triangle:"))
p=a+b+c
print("perimeter of triangle:",p)
l=float(input("enter length of rectangle:"))
w=float(input("enter width of rectangle:"))
p=2*(l+w)
print("perimeter of rectangle:",p)
s=float(input("enter side of square:"))
p=4*s
print("perimeter of square:",p)
# Out:
# enter radius of circle:3
# perimeter of circle: 18.84
# enter 1st side of triangle:2
# enter 2nd side of triangle:4
# enter 3rd side of triangle:5
# perimeter of triangle: 11.0
# enter length of rectangle:7
# enter width of rectangle:6
# perimeter of rectangle: 26.0
# enter side of square:4
# perimeter of square: 16.0

# %% [markdown]
# calculate total and average of 3 subject

# %%
E=int(input("enter marks of english:"))
M=int(input("enter marks of maths:"))
H=int(input("enter marks of hindi:"))
total = E+M+H
Average = total/3
print("Total marks:",total)
print("Average =",Average)
# Out:
# enter marks of english:80
# enter marks of maths:80
# enter marks of hindi:90
# Total marks: 250
# Average = 83.33333333333333

# %% [markdown]
# Largest of 3 numbers using simple if,else if ,else if ladder and nested if

# %% [markdown]
# simple if

# %%
a=int(input("enter 1st number:"))
b=int(input("enter 2nd number:"))
c=int(input("enter 3rd number:"))
largest=a
if b>=largest:
  largest=b
if c>=largest:
  largest=c
print(largest,"is largest")
# Out:
# enter 1st number:20
# enter 2nd number:40
# enter 3rd number:30
# 40 is largest

# %% [markdown]
# else if

# %%
a=int(input("enter 1st number:"))
b=int(input("enter 2nd number:"))
c=int(input("enter 3rd number:"))
if a>=b and a>=c:
  print(a,"is largest")
elif b>=a and b>=c:
  print(b,"is largest")
else:
  print(c,"is largest")
# Out:
# enter 1st number:20
# enter 2nd number:40
# enter 3rd number:10
# 40 is largest

# %% [markdown]
# nested if

# %%
a=int(input("enter 1st number:"))
b=int(input("enter 2nd number:"))
c=int(input("enter 3rd number:"))
if a>b:
  if a>c:
    print(a,"is largest")
  else:
    print(c,"is largest")
elif b>a:
  if b>c:
    print(b,"is largest")
  else:
    print(c,"is largest")
else:
  print(c, "is largest")
# Out:
# enter 1st number:30
# enter 2nd number:40
# enter 3rd number:50
# 50 is largest

# %% [markdown]
# leap year checking with simple if,if else and nested if

# %%
y=int(input("enter year:"))
if (y%400==0) or (y%4 ==0 and y%100!=0)*:
  print(y,"is leap year")
else:
  print(y,"is not leap year")
# Out:
# enter year:2024
# 2024 is leap year

# %% [markdown]
# nested if

# %%
y=int(input("enter year:"))
if y%4==0:
  if y%100==0:
    if y%400==0:
      print(y,"is leap year")
    else:
      print(y,"is not leap year")
  else:
    print(y, "is leap year")
else:
  print(y,"is not leap year")
# Out:
# enter year:2024
# 2024 is leap year

# %% [markdown]
# vowels or consonants using if else

# %%
ch = input("enter a character:")
if ch=='a' or ch=='e' or ch=='i' or ch=='o' or ch=='u' or ch=='A' or ch=='E' or ch=='I' or ch=='O' or ch=='U':
  print(ch,"is vowel")
else:
  print(ch,"is consonant")
# Out:
# enter a character:a
# a is vowel

# %% [markdown]
# Sorting 3 numbers

# %%
a=int(input("enter 1st number:"))
b=int(input("enter 2nd number:"))
c=int(input("enter 3rd number:"))
numbers=[a,b,c]
numbers.sort()
print(numbers)
# Out:
# enter 1st number:20
# enter 2nd number:4
# enter 3rd number:50
# [4, 20, 50]
